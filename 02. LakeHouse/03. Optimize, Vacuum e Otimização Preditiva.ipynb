-- %%
DESCRIBE DETAIL vendas

-- %%
%sql
-- ver tabela
SELECT * FROM vendas;

-- %%
-- otimizar tabela para leitura
OPTIMIZE vendas;

-- %%
-- Otimizar table para leitura + Zorder by
OPTIMIZE vendas 
ZORDER BY (Id)

-- %%
SHOW TBLPROPERTIES vendas;

-- %%
ALTER TABLE vendas SET TBLPROPERTIES(
  'delta.autoOptimize.optimizeWrite' = 'true',
  'delta.autoOptimize.autoCompact' = 'true'
);

-- %%
SHOW TBLPROPERTIES vendas;

-- %%
-- aplicando Otimização preditiva para todas as tabelas( Não fazer isso em ambiente de produção)
SET spark.databricks.delta.optimizeWrite.enabled = false;
SET spark.databricks.delta.autoCompact.enabled = false;

-- %%
DESCRIBE HISTORY vendas;

-- %%
-- por padrão limpa os arquivos parquet maior que sete dias
-- não fazer em produção
VACUUM default.vendas

-- %%
SHOW TBLPROPERTIES vendas

-- %%
VACUUM default.vendas RETAIN 0 HOURS

-- %%
-- desativar padrão de limpeza de 7 dias de arquivos parquet
ALTER TABLE default.vendas SET TBLPROPERTIES (
  'delta.logRetentionDuration' = 'interval 0 hours',
  'delta.deletedFileRetentionDuration' = 'interval 0 hours'
  );

-- %%
SHOW TBLPROPERTIES vendas;

-- %%
VACUUM vendas RETAIN 0 HOURS

-- %%
-- Outro Comanda para fazer a mesma ação - Desativar o padrão de 7 dias para Vacuum (Global)
set spark.databricks.delta.retentionDurationCheck.enabled = false;

-- %%
-- deletar tabelas
DROP table default.vendas_version_1;
