# %% [markdown]
# ##### DBFS e dbutils Documentação Azure
#
# O que é DBFS?
#
# https://learn.microsoft.com/pt-pt/azure/databricks/dbfs/
#
# Recomendações para trabalhar com a raiz DBFS
#
# https://learn.microsoft.com/pt-pt/azure/databricks/dbfs/dbfs-root
#
# Referência de Utilitários Databricks (dbutils)
#
# https://learn.microsoft.com/pt-pt/azure/databricks/dev-tools/databricks-utils

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %% [markdown]
# ####Traduzido
# cp: Copia arquivo/diretório para outro local (recursivo opcional).
#
# head: Retorna os primeiros bytes de um arquivo como string UTF-8.
#
# ls: Lista o conteúdo de um diretório.
#
# mkdirs: Cria diretório, incluindo diretórios-pai se necessário.
#
# mv: Move arquivo/diretório para outro local (recursivo opcional).
#
# put: Escreve string em um arquivo como UTF-8 (sobrescrita opcional).
#
# rm: Remove arquivo/diretório (recursivo opcional).
#
# "Recursivo" significa que a operação será aplicada de forma repetitiva a todos os itens dentro de uma estrutura, como subdiretórios e arquivos contidos em um diretório.

# %%
dbutils.fs.ls('/')

# %%
display(dbutils.fs.ls('/'))

# %%
#ver de uma forma mais amigavel display()
display(dbutils.fs.ls('/'))

# %%
display(dbutils.fs.ls('/Volumes/workspace/default/mnt/'))

# %%
dbutils.fs.mkdirs('dbfs:/Volumes/workspace/default/mnt/clients')

# %%
dbutils.fs.ls('dbfs:/Volumes/workspace/default/mnt/clients')

# %%
dbutils.fs.mkdirs('dbfs:/FileStore/Clientes')

# %%
#renomear Ajustando  erro
dbutils.fs.mv('dbfs:/FileStore/Clintes/','dbfs:/FileStore/Clientes/',True)

# %%
display(dbutils.fs.ls('/Volumes/workspace/default/mnt/clients/'))

# %%
arquivo_clientes = '/Volumes/workspace/default/mnt/clients/Clientes.csv'
df = spark.read.csv(arquivo_clientes, header=True, inferSchema=True, sep=',')
display(df)

# %%
#spark.read.csv   = comando spark para ler arquivo
#header=True      = primeira linha é o cabeçalho?
#inferSchema=True = inferir o tipo de dados automaticamente
#sep=','          = separador do arquivo CSV

# %%
list = dbutils.fs.ls('/Volumes/workspace/default/mnt/clients/')
display(list)

# %%
dbutils.fs.rm('/Volumes/workspace/default/mnt/clients/Clientes - Copia.csv')

# %%
display(dbutils.fs.ls('/Volumes/workspace/default/mnt/clients/'))

# %%
dbutils.fs.rm('/Volumes/workspace/default/mnt/clients', recurse=True)

# %%
display(dbutils.fs.ls('/Volumes/workspace/default/mnt/'))

# %%
# Criando pasta
dbutils.fs.mkdirs('/Volumes/workspace/default/mnt/produtos')

# %%
#Criando Subpasta
dbutils.fs.mkdirs('/Volumes/workspace/default/mnt/produtos/subpasta')

# %%
dbutils.fs.rm('/Volumes/workspace/default/mnt', recurse=True)

# %% [markdown]
# Dataset Databricks

# %%
display(dbutils.fs.ls('/'))

# %%
display(dbutils.fs.ls('/databricks-datasets/'))

# %%
display(dbutils.fs.ls('/databricks-datasets/wine-quality/'))

# %%
df = spark.read.csv('/databricks-datasets/wine-quality/winequality-red.csv', header=True, inferSchema=True, sep=';')
display(df)

# %% [markdown]
# Assistente IA

# %%
arquivo_clientes = 'dbfs:/FileStore/Clientes/Clientes.csv'
df = spark.read.csv(arquivo_clientes, header=True, inferSchema=True, sep=',')
display(df)

# %%
arquivo_clientes = 'dbfs:/FileStore/Clientes/Clientes.csv'
df = spark.read.csv(
    arquivo_clientes, 
    header=True, 
    inferSchema=True, 
    sep=','
)
display(df)

# %%
arquivo_clientes = 'dbfs:/FileStore/Clientes/Clientes.csv'
dbutils.fs.rm(arquivo_clientes)

# %%
#Inserir arquivo duplicado para deletar apenas um arquivo selecionado

# %%
display(dbutils.fs.ls('/FileStore/Clientes'))

# %%
#Deletar Arquivo duplicado
dbutils.fs.rm('dbfs:/FileStore/Clientes/Clientes___Copia__4_.csv')

# %%
dbutils.fs.rm('dbfs:/FileStore/Clientes',recurse=True)

# %%
display(dbutils.fs.ls('dbfs:/FileStore/Produto/Subpasta2'))

# %%
#Criando Subpastas
dbutils.fs.mkdirs('dbfs:/FileStore/Produto/Subpasta3')

# %%
display(dbutils.fs.ls('dbfs:/FileStore/'))

# %%
#Deletar pasta com tudo dentro
dbutils.fs.rm('dbfs:/FileStore/Teste/',recurse=True)

# %% [markdown]
# DataSets para voce treinar

# %%
dbutils.fs.ls('/')

# %%
#Datasets para treino
display(dbutils.fs.ls('/databricks-datasets'))

# %%
display(dbutils.fs.ls('/databricks-datasets/wine-quality/'))# ver o que tem na pasta de Vinhos

# %%
spark.read.csv('dbfs:/databricks-datasets/wine-quality/winequality-white.csv',header=True , inferSchema=True , sep=';').show(5)

# %%
# Ver de forma mais amigavel
display (spark.read.csv('dbfs:/databricks-datasets/wine-quality/winequality-white.csv',header=True , inferSchema=True , sep=';'))

# %%
df_vinhos =spark.read.csv('dbfs:/databricks-datasets/wine-quality/winequality-white.csv',header=True , inferSchema=True , sep=';')
display(df_vinhos)

# %%
display(dbutils.fs.ls('/databricks-datasets/COVID/coronavirusdataset/'))

# %%
arquivo ="dbfs:/databricks-datasets/COVID/coronavirusdataset/SearchTrend.csv"
df_covid=spark.read.csv(arquivo,header=True , inferSchema=True )
display(df_covid)

# %%
display(dbutils.fs.ls('dbfs:/databricks-datasets/bikeSharing/data-001/'))

# %%
arquivo_bike = "dbfs:/databricks-datasets/bikeSharing/data-001/day.csv"
df_bike = spark.read.csv(arquivo_bike, header=True, inferSchema=True)
display(df_bike)
